# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
data = pd.read_csv('ZomatoChennai.csv')
data
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %%
data.shape
# Out:
# (12032, 12)

# %%
data.isna().sum()
# Out:
# Zomato URL               0
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
data.replace(to_replace = ['None','Invalid','Does not offer Delivery','Does not offer Dining','Not enough Delivery Reviews','Not enough Dining Reviews'], value =np.nan,inplace=True)
data.isna().sum()
# Out:
# Zomato URL                  0
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes               9641
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count      5351
# Delivery Rating          5851
# Delivery Rating Count    5851
# Features                    0
# dtype: int64

# %%
data1 = data.drop(['Location','Top Dishes', 'Delivery Rating', 'Delivery Rating Count','Features'],axis=1,inplace=False)
data1.isna().sum()
# Out:
# Zomato URL                0
# Name of Restaurant        0
# Address                   0
# Cuisine                   0
# Price for 2               0
# Dining Rating          5351
# Dining Rating Count    5351
# dtype: int64

# %%
df = data1.dropna(subset=["Dining Rating","Dining Rating Count"],axis = 0,inplace = False)
df.reset_index(drop=True, inplace=True)
df.isna().sum()
# Out:
# Zomato URL             0
# Name of Restaurant     0
# Address                0
# Cuisine                0
# Price for 2            0
# Dining Rating          0
# Dining Rating Count    0
# dtype: int64

# %%
df
# Out:
#                                              Zomato URL  \
# 0     https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1     https://www.zomato.com/chennai/sukkubhai-biriy...
# 2     https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3           https://www.zomato.com/chennai/kfc-perambur
# 4     https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                 ...
# 6676  https://www.zomato.com/chennai/kekiz-the-cake-...
# 6677  https://www.zomato.com/chennai/engineers-kitch...
# 6678  https://www.zomato.com/chennai/that-juice-shop...
# 6679  https://www.zomato.com/chennai/amma-unavagam-k...
# 6680  https://www.zomato.com/chennai/amma-unavagam-5...
#
#          Name of Restaurant  \
# 0     Yaa Mohaideen Briyani
# 1        Sukkubhai Biriyani
# 2      SS Hyderabad Biryani
# 3                       KFC
# 4             Tasty Kitchen
# ...                     ...
# 6676    Kekiz The Cake Shop
# 6677      Engineers Kitchen
# ...

# %%
len(df["Name of Restaurant"].unique().tolist())
# Out:
# 4755

# %%
len(df['Address'].unique().tolist())
# Out:
# 6384

# %%
df.groupby(['Name of Restaurant'])['Dining Rating'].max()
# Out:
# Name of Restaurant
# 10 Muffins          2.0
# 101 Dosa            3.6
# 11 O Cafe           3.8
# 11-Eleven Pizza     3.8
# 175 ECR             3.1
#                    ...
# Zwarma              3.5
# i-Way Restaurant    3.8
# iBriyani            3.4
# ibaco               4.2
# nEATo Foods         3.3
# Name: Dining Rating, Length: 4755, dtype: object

# %%
df[df['Name of Restaurant'] == 'KFC']
# Out:
#                                              Zomato URL Name of Restaurant  \
# 3           https://www.zomato.com/chennai/kfc-perambur                KFC
# 4852       https://www.zomato.com/chennai/kfc-chromepet                KFC
# 4853     https://www.zomato.com/chennai/kfc-ashok-nagar                KFC
# 4854  https://www.zomato.com/chennai/kfc-1-nungambakkam                KFC
# 4855  https://www.zomato.com/chennai/kfc-anna-nagar-...                KFC
# 4856       https://www.zomato.com/chennai/kfc-mogappair                KFC
# 4857       https://www.zomato.com/chennai/kfc-velachery                KFC
# 4858    https://www.zomato.com/chennai/kfc-thuraipakkam                KFC
# 4859           https://www.zomato.com/chennai/kfc-porur                KFC
# 4860       https://www.zomato.com/chennai/kfc-ramapuram                KFC
# 4861         https://www.zomato.com/chennai/kfc-t-nagar                KFC
# ...

# %%
df['Name of Restaurant'] = df['Name of Restaurant'].str.upper()
df
# Out:
# <ipython-input-13-01d603e6f08b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name of Restaurant'] = df['Name of Restaurant'].str.upper()
#                                              Zomato URL  \
# 0     https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1     https://www.zomato.com/chennai/sukkubhai-biriy...
# 2     https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3           https://www.zomato.com/chennai/kfc-perambur
# 4     https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                 ...
# 6676  https://www.zomato.com/chennai/kekiz-the-cake-...
# 6677  https://www.zomato.com/chennai/engineers-kitch...
# 6678  https://www.zomato.com/chennai/that-juice-shop...
# ...

# %%
df.to_csv('data.csv')

# %%
dataframe = pd.read_csv('chennaiRestaurantData.csv')
dataframe
# Out:
#       Unnamed: 0                                         Zomato URL  \
# 0              0  https://www.zomato.com/chennai/akbar-biriyani-...
# 1              1  https://www.zomato.com/chennai/bobacha-1-perun...
# 2              2  https://www.zomato.com/chennai/burger-walla-dm...
# 3              3   https://www.zomato.com/chennai/chaat-adyar-adyar
# 4              4  https://www.zomato.com/chennai/esait-tiffen-ce...
# ...          ...                                                ...
# 4735        4735  https://www.zomato.com/chennai/shanas-kitchen-...
# 4736        4736  https://www.zomato.com/chennai/silicon-valley-...
# 4737        4737  https://www.zomato.com/chennai/sri-krishna-bak...
# 4738        4738  https://www.zomato.com/chennai/sri-muthiah-tif...
# 4739        4739  https://www.zomato.com/chennai/the-madras-deli...
#
#                               Name of Restaurant  \
# 0                                 AKBAR BIRIYANI
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4740 entries, 0 to 4739
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           4740 non-null   int64
#  1   Zomato URL           4739 non-null   object
#  2   Name of Restaurant   4738 non-null   object
#  3   Address              4738 non-null   object
#  4   Cuisine              4732 non-null   object
#  5   Price for 2          4732 non-null   object
#  6   Dining Rating        4732 non-null   object
#  7   Dining Rating Count  4731 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 296.4+ KB

# %%
dataframe['Cuisine'] = dataframe['Cuisine'].astype(str)

# %%
dataframe.isna().sum()
# Out:
# Unnamed: 0             0
# Zomato URL             0
# Name of Restaurant     0
# Address                0
# Cuisine                0
# Price for 2            0
# Dining Rating          0
# Dining Rating Count    1
# dtype: int64

# %%
lst = dataframe[dataframe['Cuisine'] == 'nan'].index.tolist()
dataframe.drop(lst,axis = 0, inplace=True)

# %%
dataframe['Cuisine'] = dataframe['Cuisine'].apply(eval)
# Out:
# Traceback (most recent call last):
#
#   File "f:\nordic internship\projects\dsbjun21\lib\site-packages\IPython\core\interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-83-5c64a29fcb31>", line 1, in <module>
#     dataframe['Cuisine'] = dataframe['Cuisine'].apply(eval)
#
#   File "f:\nordic internship\projects\dsbjun21\lib\site-packages\pandas\core\series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#
#   File "pandas\_libs\lib.pyx", line 2467, in pandas._libs.lib.map_infer
#
#   File "<string>", line 1
#     Arcot Road
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
dataframe.iloc[:,4]
# Out:
# 0             ['North Indian', ' Chinese', ' Arabian']
# 1            ['Beverages', ' Desserts', ' Bubble Tea']
# 2       ['Fast Food', ' Street Food', ' North Indian']
# 3         ['North Indian', ' Chinese', ' Street Food']
# 4                         ['South Indian', ' Chinese']
#                              ...
# 4735          ['Sandwich', ' Fast Food', ' Beverages']
# 4736                       ['Ice Cream', ' Beverages']
# 4737                          ['Bakery', ' Fast Food']
# 4738                      ['South Indian', ' Chinese']
# 4739             ['Momos', ' Fast Food', ' Beverages']
# Name: Cuisine, Length: 4732, dtype: object

# %%
lst = []
for i,value in zip(dataframe.index,dataframe['Cuisine'].values):
    for j in value:
        print(j)
# Out:
# [
# '
# N
# o
# r
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ,
#
# '
#
# C
# h
# i
# n
# e
# s
# e
# '
# ,
#
# '
#
# A
# r
# a
# b
# i
# a
# n
# '
# ]
# [
# '
# B
# e
# v
# e
# r
# a
# g
# e
# s
# '
# ,
#
# '
#
# D
# e
# s
# s
# e
# r
# t
# s
# '
# ,
#
# '
#
# B
# u
# b
# b
# l
# e
#
# T
# e
# a
# '
# ]
# [
# '
# F
# a
# s
# t
#
# F
# o
# o
# d
# '
# ,
#
# '
#
# S
# t
# r
# e
# e
# t
#
# F
# o
# o
# d
# '
# ,
#
# '
#
# N
# o
# r
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ]
# [
# '
# N
# o
# r
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ,
#
# '
#
# C
# h
# i
# n
# e
# s
# e
# '
# ,
#
# '
#
# S
# t
# r
# e
# e
# t
#
# F
# o
# o
# d
# '
# ]
# [
# '
# S
# o
# u
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ,
#
# '
#
# C
# h
# i
# n
# e
# s
# e
# '
# ]
# [
# '
# M
# e
# x
# i
# c
# a
# n
# '
# ,
#
# '
#
# I
# t
# a
# l
# i
# a
# n
# '
# ,
#
# '
#
# N
# o
# r
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ]
# [
# '
# N
# o
# r
# t
# h
#
# I
# n
# d
# i
# a
# n
# '
# ,
#
# '
#
# M
# u
# g
# h
# l
# a
# i
# '
# ,
# ...

# %%
lst
# Out:
# ["'",
#  'N',
#  'o',
#  'r',
#  't',
#  'h',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  "'",
#  ' ',
#  "'",
#  ' ',
#  'C',
#  'h',
#  'i',
#  'n',
#  'e',
#  's',
#  'e',
#  "'",
#  ' ',
#  "'",
#  ' ',
#  'A',
#  'r',
#  'a',
#  'b',
#  'i',
#  'a',
#  'n',
#  "'"]
