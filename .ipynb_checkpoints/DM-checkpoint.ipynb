# %%
import pandas as pd

# %%
data = pd.read_csv('chennaiRestaurantData.csv')
data
# Out:
#       Unnamed: 0                                         Zomato URL  \
# 0              0  https://www.zomato.com/chennai/akbar-biriyani-...
# 1              1  https://www.zomato.com/chennai/bobacha-1-perun...
# 2              2  https://www.zomato.com/chennai/burger-walla-dm...
# 3              3   https://www.zomato.com/chennai/chaat-adyar-adyar
# 4              4  https://www.zomato.com/chennai/esait-tiffen-ce...
# ...          ...                                                ...
# 4735        4735  https://www.zomato.com/chennai/shanas-kitchen-...
# 4736        4736  https://www.zomato.com/chennai/silicon-valley-...
# 4737        4737  https://www.zomato.com/chennai/sri-krishna-bak...
# 4738        4738  https://www.zomato.com/chennai/sri-muthiah-tif...
# 4739        4739  https://www.zomato.com/chennai/the-madras-deli...
#
#                               Name of Restaurant  \
# 0                                 AKBAR BIRIYANI
# ...

# %%
data1 = pd.read_csv('ZomatoConverted.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-30a0fae03a08> in <module>
# ----> 1 data1 = pd.read_csv('ZomatoConverted.csv')
#
# f:\nordic internship\projects\dsbjun21\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...
